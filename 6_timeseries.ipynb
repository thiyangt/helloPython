# %% [markdown]
# # Time Series

# %%
#import sys
#!{sys.executable} -m pip install pandas

# %%
# packages
import pandas as pd
import numpy as np
import plotnine
import datetime as dt
# %matplotlib inline

# %%
from plotnine import *

# %%
# Read data
airpassenger = pd.read_csv('AirPassengers.csv')

# %%
airpassenger
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
airpassenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
airpassenger.index
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
 airpassenger.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
from datetime import datetime

# %%
airpassenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# use original variable without coverting to datetime
airpassenger = pd.read_csv('AirPassengers.csv')

# %%
airpassenger.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
airpassenger['Month']= pd.to_datetime(airpassenger['Month'])

# %%
airpassenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
ggplot(airpassenger, aes(x='Month', y='#Passengers'))+geom_line()
# Out:
# <ggplot: (342314828)>

# %%
ggplot(airpassenger, aes(x='Month', y='#Passengers'))+geom_line() +geom_point()
# Out:
# <ggplot: (342310563)>

# %% [markdown]
# ## Split date into month and year

# %%
#airpassenger["month"] = airpassenger['Month'].map(lambda x: x.month)
#airpassenger["year"] = airpassenger['Month'].map(lambda x: x.year)
airpassenger['year'] = airpassenger['Month'].dt.year
airpassenger['month'] = airpassenger['Month'].dt.month

# %%
airpassenger.head()
# Out:
#        Month  #Passengers  year  month
# 0 1949-01-01          112  1949      1
# 1 1949-02-01          118  1949      2
# 2 1949-03-01          132  1949      3
# 3 1949-04-01          129  1949      4
# 4 1949-05-01          121  1949      5

# %%
airpassenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
#  2   year         144 non-null    int64
#  3   month        144 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 4.6 KB

# %%
airpassenger.describe()
# Out:
#        #Passengers         year       month
# count   144.000000   144.000000  144.000000
# mean    280.298611  1954.500000    6.500000
# std     119.966317     3.464102    3.464102
# min     104.000000  1949.000000    1.000000
# 25%     180.000000  1951.750000    3.750000
# 50%     265.500000  1954.500000    6.500000
# 75%     360.500000  1957.250000    9.250000
# max     622.000000  1960.000000   12.000000

# %%
ggplot(airpassenger, aes(x='month', y='#Passengers', color='year'))+geom_point()
# Out:
# <ggplot: (343702944)>

# %% [markdown]
# ## Visualizing birth dataset

# %%
birth_reduced = pd.read_csv('birth_reduced.csv')

# %%
birth_reduced.info()

# %%
birth_reduced.head()

# %%
# count number of observations for each disease by year of birth
yearly_counts = birth_reduced.groupby(['year_of_birth', 'disease'])['disease'].count()
yearly_counts.head()

# %%
yearly_counts.info()

# %%
yearly_counts = yearly_counts.reset_index(name='counts')
yearly_counts.head()

# %%
yearly_counts.info()

# %%
# plot all counts by year
ggplot(yearly_counts, aes(x='year_of_birth', y='counts'))+ geom_line()

# %%
from plotnine import *
from plotnine.data import *

# %%
economics.head()
# Out:
#         date    pce     pop  psavert  uempmed  unemploy
# 0 1967-07-01  507.4  198712     12.5      4.5      2944
# 1 1967-08-01  510.5  198911     12.5      4.7      2945
# 2 1967-09-01  516.3  199113     11.7      4.6      2958
# 3 1967-10-01  512.9  199311     12.5      4.9      3143
# 4 1967-11-01  518.1  199498     12.5      4.7      3066

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    datetime64[ns]
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    int64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 27.0 KB

# %%
(
    ggplot(economics, aes(x='date', y='uempmed')) 
    + geom_line() # line plot
    + labs(x='date', y='median duration of unemployment')
)
# Out:
# <ggplot: (272797254)>

# %%
## Resources
https://github.com/insiderhack/arima-timeseries-airplane
